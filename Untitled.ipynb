# %%
# Install Pytorch & other libraries
# %pip install "torch==2.4.1" tensorboard 
# %pip install flash-attn "setuptools<71.0.0" scikit-learn 
 
# Install Hugging Face libraries
# %pip install  --upgrade \
  "datasets==3.1.0" \
  "accelerate==1.2.1" \
  "hf-transfer==0.1.8"
  #"transformers==4.47.1" \
 
# ModernBERT is not yet available in an official release, so we need to install it from github
# %pip install "git+https://github.com/huggingface/transformers.git@6e0515e99c39444caae39472ee1b2fd76ece32f1" --upgrade
# Out:
# ERROR: Could not find a version that satisfies the requirement torch==2.4.1 (from versions: 2.6.0, 2.7.0, 2.7.1, 2.8.0, 2.9.0, 2.9.1, 2.10.0, 2.11.0, 2.12.0, 2.12.1)
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# ERROR: No matching distribution found for torch==2.4.1
# Note: you may need to restart the kernel to use updated packages.
# Collecting flash-attn
#   Downloading flash_attn-2.8.3.post1.tar.gz (8.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.5/8.5 MB 10.8 MB/s eta 0:00:00 MB/s eta 0:00:01:01
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... error
#   error: subprocess-exited-with-error
#
#   × Getting requirements to build wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [25 lines of output]
#       /private/var/folders/g2/6vrxjr0j1jz38tb_gyyggfb00000gn/T/pip-build-env-qu_1_p85/overlay/lib/python3.13/site-packages/setuptools/_vendor/wheel/bdist_wheel.py:4: FutureWarning: The 'wheel' package is no longer the canonical location of the 'bdist_wheel' command, and will be removed in a future release. Please update to setuptools v70.1 or later which contains an integrated version of this command.
#         warn(
#       Traceback (most recent call last):
#         File "/Users/soumanpaul/Desktop/Desk/projects/ai-projects/intelegent-llm-router/.venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 353, in <module>
#           main()
#           ~~~~^^
#         File "/Users/soumanpaul/Desktop/Desk/projects/ai-projects/intelegent-llm-router/.venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 335, in main
#           json_out['return_val'] = hook(**hook_input['kwargs'])
#                                    ~~~~^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/Users/soumanpaul/Desktop/Desk/projects/ai-projects/intelegent-llm-router/.venv/lib/python3.13/site-packages/pip/_vendor/pyproject_hooks/_in_process/_in_process.py", line 118, in get_requires_for_build_wheel
#           return hook(config_settings)
#         File "/private/var/folders/g2/6vrxjr0j1jz38tb_gyyggfb00000gn/T/pip-build-env-qu_1_p85/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 333, in get_requires_for_build_wheel
#           return self._get_build_requires(config_settings, requirements=[])
#                  ~~~~~~~~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/g2/6vrxjr0j1jz38tb_gyyggfb00000gn/T/pip-build-env-qu_1_p85/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 301, in _get_build_requires
#           self.run_setup()
#           ~~~~~~~~~~~~~~^^
#         File "/private/var/folders/g2/6vrxjr0j1jz38tb_gyyggfb00000gn/T/pip-build-env-qu_1_p85/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 520, in run_setup
#           super().run_setup(setup_script=setup_script)
#           ~~~~~~~~~~~~~~~~~^^^^^^^^^^^^^^^^^^^^^^^^^^^
#         File "/private/var/folders/g2/6vrxjr0j1jz38tb_gyyggfb00000gn/T/pip-build-env-qu_1_p85/overlay/lib/python3.13/site-packages/setuptools/build_meta.py", line 317, in run_setup
#           exec(code, locals())
#           ~~~~^^^^^^^^^^^^^^^^
#         File "<string>", line 22, in <module>
#       ModuleNotFoundError: No module named 'torch'
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# error: subprocess-exited-with-error
#
# × Getting requirements to build wheel did not run successfully.
# │ exit code: 1
# ╰─> See above for output.
#
# note: This error originates from a subprocess, and is likely not a problem with pip.
# Note: you may need to restart the kernel to use updated packages.
# Collecting datasets==3.1.0
#   Downloading datasets-3.1.0-py3-none-any.whl.metadata (20 kB)
# Collecting accelerate==1.2.1
#   Downloading accelerate-1.2.1-py3-none-any.whl.metadata (19 kB)
# Collecting hf-transfer==0.1.8
#   Downloading hf_transfer-0.1.8.tar.gz (23 kB)
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Collecting filelock (from datasets==3.1.0)
#   Downloading filelock-3.29.4-py3-none-any.whl.metadata (2.0 kB)
# Collecting numpy>=1.17 (from datasets==3.1.0)
#   Downloading numpy-2.5.0-cp313-cp313-macosx_14_0_arm64.whl.metadata (6.6 kB)
# Collecting pyarrow>=15.0.0 (from datasets==3.1.0)
#   Downloading pyarrow-24.0.0-cp313-cp313-macosx_12_0_arm64.whl.metadata (3.0 kB)
# Collecting dill<0.3.9,>=0.3.0 (from datasets==3.1.0)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Collecting pandas (from datasets==3.1.0)
#   Downloading pandas-3.0.3-cp313-cp313-macosx_11_0_arm64.whl.metadata (79 kB)
# Requirement already satisfied: requests>=2.32.2 in ./.venv/lib/python3.13/site-packages (from datasets==3.1.0) (2.34.2)
# Collecting tqdm>=4.66.3 (from datasets==3.1.0)
#   Downloading tqdm-4.68.3-py3-none-any.whl.metadata (57 kB)
# Collecting xxhash (from datasets==3.1.0)
#   Downloading xxhash-3.8.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (14 kB)
# Collecting multiprocess<0.70.17 (from datasets==3.1.0)
#   Downloading multiprocess-0.70.16-py312-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.9.0,>=2023.1.0 (from fsspec[http]<=2024.9.0,>=2023.1.0->datasets==3.1.0)
#   Downloading fsspec-2024.9.0-py3-none-any.whl.metadata (11 kB)
# Collecting aiohttp (from datasets==3.1.0)
#   Downloading aiohttp-3.14.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (8.3 kB)
# Collecting huggingface-hub>=0.23.0 (from datasets==3.1.0)
#   Downloading huggingface_hub-1.21.0-py3-none-any.whl.metadata (14 kB)
# Requirement already satisfied: packaging in ./.venv/lib/python3.13/site-packages (from datasets==3.1.0) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.13/site-packages (from datasets==3.1.0) (6.0.3)
# Requirement already satisfied: psutil in ./.venv/lib/python3.13/site-packages (from accelerate==1.2.1) (7.2.2)
# Collecting torch>=1.10.0 (from accelerate==1.2.1)
#   Downloading torch-2.12.1-cp313-cp313-macosx_14_0_arm64.whl.metadata (31 kB)
# Collecting safetensors>=0.4.3 (from accelerate==1.2.1)
#   Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl.metadata (4.2 kB)
# Collecting aiohappyeyeballs>=2.5.0 (from aiohttp->datasets==3.1.0)
#   Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl.metadata (5.9 kB)
# Collecting aiosignal>=1.4.0 (from aiohttp->datasets==3.1.0)
#   Downloading aiosignal-1.4.0-py3-none-any.whl.metadata (3.7 kB)
# Requirement already satisfied: attrs>=17.3.0 in ./.venv/lib/python3.13/site-packages (from aiohttp->datasets==3.1.0) (26.1.0)
# Collecting frozenlist>=1.1.1 (from aiohttp->datasets==3.1.0)
#   Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl.metadata (20 kB)
# Collecting multidict<7.0,>=4.5 (from aiohttp->datasets==3.1.0)
#   Downloading multidict-6.7.1-cp313-cp313-macosx_11_0_arm64.whl.metadata (5.3 kB)
# Collecting propcache>=0.2.0 (from aiohttp->datasets==3.1.0)
#   Downloading propcache-0.5.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (16 kB)
# Collecting yarl<2.0,>=1.17.0 (from aiohttp->datasets==3.1.0)
#   Downloading yarl-1.24.2-cp313-cp313-macosx_11_0_arm64.whl.metadata (94 kB)
# Collecting click>=8.4.0 (from huggingface-hub>=0.23.0->datasets==3.1.0)
#   Downloading click-8.4.2-py3-none-any.whl.metadata (2.6 kB)
# Collecting hf-xet<2.0.0,>=1.5.1 (from huggingface-hub>=0.23.0->datasets==3.1.0)
#   Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl.metadata (4.9 kB)
# Requirement already satisfied: httpx<1,>=0.23.0 in ./.venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->datasets==3.1.0) (0.28.1)
# Collecting typer<0.26.0,>=0.20.0 (from huggingface-hub>=0.23.0->datasets==3.1.0)
#   Downloading typer-0.25.1-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: typing-extensions>=4.1.0 in ./.venv/lib/python3.13/site-packages (from huggingface-hub>=0.23.0->datasets==3.1.0) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets==3.1.0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets==3.1.0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets==3.1.0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.13/site-packages (from requests>=2.32.2->datasets==3.1.0) (2026.6.17)
# Collecting setuptools<82 (from torch>=1.10.0->accelerate==1.2.1)
#   Downloading setuptools-81.0.0-py3-none-any.whl.metadata (6.6 kB)
# Collecting sympy>=1.13.3 (from torch>=1.10.0->accelerate==1.2.1)
#   Downloading sympy-1.14.0-py3-none-any.whl.metadata (12 kB)
# Collecting networkx>=2.5.1 (from torch>=1.10.0->accelerate==1.2.1)
#   Downloading networkx-3.6.1-py3-none-any.whl.metadata (6.8 kB)
# Requirement already satisfied: jinja2 in ./.venv/lib/python3.13/site-packages (from torch>=1.10.0->accelerate==1.2.1) (3.1.6)
# Requirement already satisfied: python-dateutil>=2.8.2 in ./.venv/lib/python3.13/site-packages (from pandas->datasets==3.1.0) (2.9.0.post0)
# Requirement already satisfied: anyio in ./.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->datasets==3.1.0) (4.14.1)
# Requirement already satisfied: httpcore==1.* in ./.venv/lib/python3.13/site-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.23.0->datasets==3.1.0) (1.0.9)
# Requirement already satisfied: h11>=0.16 in ./.venv/lib/python3.13/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.23.0->datasets==3.1.0) (0.16.0)
# Requirement already satisfied: six>=1.5 in ./.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas->datasets==3.1.0) (1.17.0)
# Collecting mpmath<1.4,>=1.1.0 (from sympy>=1.13.3->torch>=1.10.0->accelerate==1.2.1)
#   Downloading mpmath-1.3.0-py3-none-any.whl.metadata (8.6 kB)
# Collecting shellingham>=1.3.0 (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->datasets==3.1.0)
#   Downloading shellingham-1.5.4-py2.py3-none-any.whl.metadata (3.5 kB)
# Collecting rich>=13.8.0 (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->datasets==3.1.0)
#   Downloading rich-15.0.0-py3-none-any.whl.metadata (18 kB)
# Collecting annotated-doc>=0.0.2 (from typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->datasets==3.1.0)
#   Downloading annotated_doc-0.0.4-py3-none-any.whl.metadata (6.6 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in ./.venv/lib/python3.13/site-packages (from jinja2->torch>=1.10.0->accelerate==1.2.1) (3.0.3)
# Collecting markdown-it-py>=2.2.0 (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->datasets==3.1.0)
#   Downloading markdown_it_py-4.2.0-py3-none-any.whl.metadata (7.4 kB)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in ./.venv/lib/python3.13/site-packages (from rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->datasets==3.1.0) (2.20.0)
# Collecting mdurl~=0.1 (from markdown-it-py>=2.2.0->rich>=13.8.0->typer<0.26.0,>=0.20.0->huggingface-hub>=0.23.0->datasets==3.1.0)
#   Downloading mdurl-0.1.2-py3-none-any.whl.metadata (1.6 kB)
# Downloading datasets-3.1.0-py3-none-any.whl (480 kB)
# Downloading accelerate-1.2.1-py3-none-any.whl (336 kB)
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
# Downloading fsspec-2024.9.0-py3-none-any.whl (179 kB)
# Downloading aiohttp-3.14.1-cp313-cp313-macosx_11_0_arm64.whl (508 kB)
# Downloading huggingface_hub-1.21.0-py3-none-any.whl (721 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 721.1/721.1 kB 9.8 MB/s eta 0:00:00
# Downloading filelock-3.29.4-py3-none-any.whl (42 kB)
# Downloading multiprocess-0.70.16-py312-none-any.whl (146 kB)
# Downloading numpy-2.5.0-cp313-cp313-macosx_14_0_arm64.whl (5.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 11.2 MB/s eta 0:00:0031m11.7 MB/s eta 0:00:01
# Downloading pyarrow-24.0.0-cp313-cp313-macosx_12_0_arm64.whl (35.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 35.0/35.0 MB 10.6 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading safetensors-0.8.0-cp310-abi3-macosx_11_0_arm64.whl (484 kB)
# Downloading torch-2.12.1-cp313-cp313-macosx_14_0_arm64.whl (88.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 88.0/88.0 MB 11.0 MB/s eta 0:00:00m eta 0:00:010:01:01
# Downloading tqdm-4.68.3-py3-none-any.whl (78 kB)
# Downloading pandas-3.0.3-cp313-cp313-macosx_11_0_arm64.whl (9.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 9.9/9.9 MB 10.5 MB/s eta 0:00:00 MB/s eta 0:00:01:01
# Downloading xxhash-3.8.0-cp313-cp313-macosx_11_0_arm64.whl (32 kB)
# Downloading aiohappyeyeballs-2.7.1-py3-none-any.whl (15 kB)
# Downloading aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Downloading click-8.4.2-py3-none-any.whl (119 kB)
# Downloading frozenlist-1.8.0-cp313-cp313-macosx_11_0_arm64.whl (49 kB)
# Downloading hf_xet-1.5.1-cp37-abi3-macosx_11_0_arm64.whl (3.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.8/3.8 MB 10.6 MB/s eta 0:00:0031m11.7 MB/s eta 0:00:01
# Downloading multidict-6.7.1-cp313-cp313-macosx_11_0_arm64.whl (43 kB)
# Downloading networkx-3.6.1-py3-none-any.whl (2.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.1 MB/s eta 0:00:00
# Downloading propcache-0.5.2-cp313-cp313-macosx_11_0_arm64.whl (54 kB)
# Downloading setuptools-81.0.0-py3-none-any.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 9.0 MB/s eta 0:00:00
# Downloading sympy-1.14.0-py3-none-any.whl (6.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.3/6.3 MB 10.9 MB/s eta 0:00:0031m11.7 MB/s eta 0:00:01
# Downloading typer-0.25.1-py3-none-any.whl (58 kB)
# Downloading yarl-1.24.2-cp313-cp313-macosx_11_0_arm64.whl (91 kB)
# Downloading annotated_doc-0.0.4-py3-none-any.whl (5.3 kB)
# Downloading mpmath-1.3.0-py3-none-any.whl (536 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 536.2/536.2 kB 8.0 MB/s eta 0:00:00
# Downloading rich-15.0.0-py3-none-any.whl (310 kB)
# Downloading shellingham-1.5.4-py2.py3-none-any.whl (9.8 kB)
# Downloading markdown_it_py-4.2.0-py3-none-any.whl (91 kB)
# Downloading mdurl-0.1.2-py3-none-any.whl (10.0 kB)
# Building wheels for collected packages: hf-transfer
#   Building wheel for hf-transfer (pyproject.toml) ... done
#   Created wheel for hf-transfer: filename=hf_transfer-0.1.8-cp313-cp313-macosx_11_0_arm64.whl size=1400261 sha256=9ab1f27a4390315595b3c9bef870d052f61ef5f7a6f4920a250b91439e71b1e4
#   Stored in directory: /Users/soumanpaul/Library/Caches/pip/wheels/92/21/00/ecffbae7ab341577e28c2f6208f95cfe5bc19fe85d220b32c3
# Successfully built hf-transfer
# Installing collected packages: mpmath, xxhash, tqdm, sympy, shellingham, setuptools, safetensors, pyarrow, propcache, numpy, networkx, multidict, mdurl, hf-xet, hf-transfer, fsspec, frozenlist, filelock, dill, click, annotated-doc, aiohappyeyeballs, yarl, torch, pandas, multiprocess, markdown-it-py, aiosignal, rich, aiohttp, typer, huggingface-hub, datasets, accelerate
# Successfully installed accelerate-1.2.1 aiohappyeyeballs-2.7.1 aiohttp-3.14.1 aiosignal-1.4.0 annotated-doc-0.0.4 click-8.4.2 datasets-3.1.0 dill-0.3.8 filelock-3.29.4 frozenlist-1.8.0 fsspec-2024.9.0 hf-transfer-0.1.8 hf-xet-1.5.1 huggingface-hub-1.21.0 markdown-it-py-4.2.0 mdurl-0.1.2 mpmath-1.3.0 multidict-6.7.1 multiprocess-0.70.16 networkx-3.6.1 numpy-2.5.0 pandas-3.0.3 propcache-0.5.2 pyarrow-24.0.0 rich-15.0.0 safetensors-0.8.0 setuptools-81.0.0 shellingham-1.5.4 sympy-1.14.0 torch-2.12.1 tqdm-4.68.3 typer-0.25.1 xxhash-3.8.0 yarl-1.24.2
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Collecting git+https://github.com/huggingface/transformers.git@6e0515e99c39444caae39472ee1b2fd76ece32f1
#   Cloning https://github.com/huggingface/transformers.git (to revision 6e0515e99c39444caae39472ee1b2fd76ece32f1) to /private/var/folders/g2/6vrxjr0j1jz38tb_gyyggfb00000gn/T/pip-req-build-7bbjno6i
#   Running command git clone --filter=blob:none --quiet https://github.com/huggingface/transformers.git /private/var/folders/g2/6vrxjr0j1jz38tb_gyyggfb00000gn/T/pip-req-build-7bbjno6i
#   Running command git rev-parse -q --verify 'sha^6e0515e99c39444caae39472ee1b2fd76ece32f1'
#   Running command git fetch -q https://github.com/huggingface/transformers.git 6e0515e99c39444caae39472ee1b2fd76ece32f1
#   Running command git checkout -q 6e0515e99c39444caae39472ee1b2fd76ece32f1
#   Resolved https://github.com/huggingface/transformers.git to commit 6e0515e99c39444caae39472ee1b2fd76ece32f1
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# Requirement already satisfied: filelock in ./.venv/lib/python3.13/site-packages (from transformers==4.48.0.dev0) (3.29.4)
# Collecting huggingface-hub<1.0,>=0.24.0 (from transformers==4.48.0.dev0)
#   Downloading huggingface_hub-0.36.2-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: numpy>=1.17 in ./.venv/lib/python3.13/site-packages (from transformers==4.48.0.dev0) (2.5.0)
# Requirement already satisfied: packaging>=20.0 in ./.venv/lib/python3.13/site-packages (from transformers==4.48.0.dev0) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in ./.venv/lib/python3.13/site-packages (from transformers==4.48.0.dev0) (6.0.3)
# Collecting regex!=2019.12.17 (from transformers==4.48.0.dev0)
#   Downloading regex-2026.6.28-cp313-cp313-macosx_11_0_arm64.whl.metadata (40 kB)
# Requirement already satisfied: requests in ./.venv/lib/python3.13/site-packages (from transformers==4.48.0.dev0) (2.34.2)
# Collecting tokenizers<0.22,>=0.21 (from transformers==4.48.0.dev0)
#   Downloading tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl.metadata (6.7 kB)
# Requirement already satisfied: safetensors>=0.4.1 in ./.venv/lib/python3.13/site-packages (from transformers==4.48.0.dev0) (0.8.0)
# Requirement already satisfied: tqdm>=4.27 in ./.venv/lib/python3.13/site-packages (from transformers==4.48.0.dev0) (4.68.3)
# Requirement already satisfied: fsspec>=2023.5.0 in ./.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.0.dev0) (2024.9.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.3 in ./.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.0.dev0) (1.5.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in ./.venv/lib/python3.13/site-packages (from huggingface-hub<1.0,>=0.24.0->transformers==4.48.0.dev0) (4.16.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in ./.venv/lib/python3.13/site-packages (from requests->transformers==4.48.0.dev0) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in ./.venv/lib/python3.13/site-packages (from requests->transformers==4.48.0.dev0) (3.18)
# Requirement already satisfied: urllib3<3,>=1.26 in ./.venv/lib/python3.13/site-packages (from requests->transformers==4.48.0.dev0) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in ./.venv/lib/python3.13/site-packages (from requests->transformers==4.48.0.dev0) (2026.6.17)
# Downloading huggingface_hub-0.36.2-py3-none-any.whl (566 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 566.4/566.4 kB 9.0 MB/s eta 0:00:00
# Downloading regex-2026.6.28-cp313-cp313-macosx_11_0_arm64.whl (289 kB)
# Downloading tokenizers-0.21.4-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.7/2.7 MB 10.8 MB/s eta 0:00:0031m11.8 MB/s eta 0:00:01
# Building wheels for collected packages: transformers
#   Building wheel for transformers (pyproject.toml) ... done
#   Created wheel for transformers: filename=transformers-4.48.0.dev0-py3-none-any.whl size=10328692 sha256=73a9060f96fe5e9051693a1732f5665720ed6377059c2ecce057c111576f5fdc
#   Stored in directory: /Users/soumanpaul/Library/Caches/pip/wheels/91/4b/b7/9b87d1c117c05606a4d203045857f833d189cc8f55779d3bec
# Successfully built transformers
# Installing collected packages: regex, huggingface-hub, tokenizers, transformers
#   Attempting uninstall: huggingface-hub
#     Found existing installation: huggingface_hub 1.21.0
#     Uninstalling huggingface_hub-1.21.0:
#       Successfully uninstalled huggingface_hub-1.21.0
# Successfully installed huggingface-hub-0.36.2 regex-2026.6.28 tokenizers-0.21.4 transformers-4.48.0.dev0
#
# [notice] A new release of pip is available: 24.3.1 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from datasets import load_dataset
 
# Dataset id from huggingface.co/dataset
# dataset_id = "DevQuasar/llm_router_dataset-synth"
dataset_id = "legacy-datasets/banking77"
 
# Load raw dataset
raw_dataset = load_dataset(dataset_id)
 
print(f"Train dataset size: {len(raw_dataset['train'])}")
print(f"Test dataset size: {len(raw_dataset['test'])}")
# Out:
# Train dataset size: 10003
# Test dataset size: 3080

# %%
from random import randrange
 
random_id = randrange(len(raw_dataset['train']))
raw_dataset['train'][random_id]
# {'id': '6225a9cd-5cba-4840-8e21-1f9cf2ded7e6',
# 'prompt': 'How many legs does a spider have?',
# 'label': 0}
# Out:
# {'text': 'how can the money machine keep my card what do i need to do?',
#  'label': 18}

# %%
raw_dataset["train"].features
# Out:
# {'text': Value(dtype='string', id=None),
#  'label': ClassLabel(names=['activate_my_card', 'age_limit', 'apple_pay_or_google_pay', 'atm_support', 'automatic_top_up', 'balance_not_updated_after_bank_transfer', 'balance_not_updated_after_cheque_or_cash_deposit', 'beneficiary_not_allowed', 'cancel_transfer', 'card_about_to_expire', 'card_acceptance', 'card_arrival', 'card_delivery_estimate', 'card_linking', 'card_not_working', 'card_payment_fee_charged', 'card_payment_not_recognised', 'card_payment_wrong_exchange_rate', 'card_swallowed', 'cash_withdrawal_charge', 'cash_withdrawal_not_recognised', 'change_pin', 'compromised_card', 'contactless_not_working', 'country_support', 'declined_card_payment', 'declined_cash_withdrawal', 'declined_transfer', 'direct_debit_payment_not_recognised', 'disposable_card_limits', 'edit_personal_details', 'exchange_charge', 'exchange_rate', 'exchange_via_app', 'extra_charge_on_statement', 'failed_transfer', 'fiat_currency_support', 'get_disposable_virtual_card', 'get_physical_card', 'getting_spare_card', 'getting_virtual_card', 'lost_or_stolen_card', 'lost_or_stolen_phone', 'order_physical_card', 'passcode_forgotten', 'pending_card_payment', 'pending_cash_withdrawal', 'pending_top_up', 'pending_transfer', 'pin_blocked', 'receiving_money', 'Refund_not_showing_up', 'request_refund', 'reverted_card_payment?', 'supported_cards_and_currencies', 'terminate_account', 'top_up_by_bank_transfer_charge', 'top_up_by_card_charge', 'top_up_by_cash_or_cheque', 'top_up_failed', 'top_up_limits', 'top_up_reverted', 'topping_up_by_card', 'transaction_charged_twice', 'transfer_fee_charged', 'transfer_into_account', 'transfer_not_received_by_recipient', 'transfer_timing', 'unable_to_verify_identity', 'verify_my_identity', 'verify_source_of_funds', 'verify_top_up', 'virtual_card_not_working', 'visa_or_mastercard', 'why_verify_identity', 'wrong_amount_of_cash_received', 'wrong_exchange_rate_for_cash_withdrawal'], id=None)}

# %%
label_id = raw_dataset["train"][random_id]["label"]
label_name = raw_dataset["train"].features["label"].int2str(label_id)

print(label_id, label_name)
# Out:
# 18 card_swallowed
